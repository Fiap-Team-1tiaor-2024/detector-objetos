# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17410, done.
# remote: Counting objects: 100% (84/84), done.
# remote: Compressing objects: 100% (62/62), done.
# remote: Total 17410 (delta 63), reused 22 (delta 22), pack-reused 17326 (from 3)
# Receiving objects: 100% (17410/17410), 16.30 MiB | 16.02 MiB/s, done.
# Resolving deltas: 100% (11934/11934), done.

# %%
! pip install -r yolov5/requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 90.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 95.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 55.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 101.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 65.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
! cp /content/drive/MyDrive/2025/copo.yaml yolov5/data/

# %%
# !python yolov5/train.py --data copo.yaml --weights yolov5s.pt --img 640 --epochs 40
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-04-28 23:33:41.101887: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745883221.326304    1550 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...

# %%
import os
import subprocess

def get_latest_train_run_folder():
    subfolders = [f.path for f in os.scandir('yolov5/runs/train') if f.is_dir()]
    latest_folder = max(subfolders, key=os.path.getctime, default=None)
    return latest_folder

latest_run = get_latest_train_run_folder()
result = subprocess.run(f'python yolov5/detect.py --weights {latest_run}/weights/best.pt --img 640 --source /content/drive/MyDrive/2025/images/test --data yolov5/data/copo.yaml', shell=True, capture_output=True, text=True)
if latest_run:
    # COMANDO
    result = subprocess.run(f'python yolov5/detect.py --weights {latest_run}/weights/best.pt --img 640 --source /content/drive/MyDrive/2025/images/test --data yolov5/data/copo.yaml', shell=True, capture_output=True, text=True)
    print(result.stdout)
    print(result.stderr)
else:
    print("Não foi possível encontrar a pasta de treinamento mais recente.")
# Out:
# detect: weights=['yolov5/runs/train/exp/weights/best.pt'], source=/content/drive/MyDrive/2025/images/test, data=yolov5/data/copo.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-416-gfe1d4d99 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/4 /content/drive/MyDrive/2025/images/test/Image (44).jpg: 480x640 1 copo, 51.5ms
# image 2/4 /content/drive/MyDrive/2025/images/test/Image (45).jpg: 480x640 2 copos, 11.3ms
# ...

# %%
# !python yolov5/train.py --data copo.yaml --weights yolov5s.pt --img 640 --epochs 60
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-04-28 23:42:44.418853: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745883764.438807    3978 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745883764.445106    3978 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout)
# ...

# %%
import os
import subprocess

def get_latest_train_run_folder():
    subfolders = [f.path for f in os.scandir('yolov5/runs/train') if f.is_dir()]
    latest_folder = max(subfolders, key=os.path.getctime, default=None)
    return latest_folder

latest_run = get_latest_train_run_folder()
result = subprocess.run(f'python yolov5/detect.py --weights {latest_run}/weights/best.pt --img 640 --source /content/drive/MyDrive/2025/images/test --data yolov5/data/copo.yaml', shell=True, capture_output=True, text=True)
if latest_run:
    # COMANDO
    result = subprocess.run(f'python yolov5/detect.py --weights {latest_run}/weights/best.pt --img 640 --source /content/drive/MyDrive/2025/images/test --data yolov5/data/copo.yaml', shell=True, capture_output=True, text=True)
    print(result.stdout)
    print(result.stderr)
else:
    print("Não foi possível encontrar a pasta de treinamento mais recente.")

# %% [markdown]
# Conclusão:
#
# MODELO 1) Informações observadas:
#
# • **Épocas: 40**
# • Tempo de treinamento: ~1.8 horas
# • Classes: 4 classes (objetos diferentes)
# • mAP50: 100%
# • mAP50-95: 69.7%
# • Precision (P): valores altos (por exemplo, 0.944)
# • Recall (R): também bons (por exemplo, 0.955)
#
# Análise:
# 1. Assertividade do modelo:
# • O mAP50 de 100% indica que o modelo é extremamente bom em identificar corretamente as classes com 50% de interseção sobre união (IoU).
# • O mAP50-95 de 69.7% mostra que, quando aumentamos o critério de exigência (de 50% até 95% de IoU), a qualidade ainda é boa, mas já não é perfeita.
# • Precision e Recall também são altos (em torno de 0.9), o que significa que:
# • Precision alto: poucos falsos positivos (não erra muito ao dizer que encontrou o objeto).
# • Recall alto: poucos falsos negativos (não deixa muitos objetos passarem sem identificar).
# Resumo de assertividade:
# O modelo está com uma assertividade muito boa para a detecção dos objetos, principalmente em condições “normais”.
#
# 2. Pontos fracos observados:
# • mAP50-95 ainda não é excelente (69.7% indica que sob critérios mais rígidos de avaliação o modelo comete erros). Isso pode ser por:
# • Erro na localização (bounding box não 100% precisa);
# • Confusão entre classes parecidas.
# • Pequeno risco de overfitting:
# • Como o mAP50 está perfeito, mas o mAP50-95 cai, é possível que o modelo tenha “memorizado” muito bem o dataset de treino, mas não generalize perfeitamente para imagens novas.
# • Quantidade pequena de dados:
# • Você usou apenas 4 imagens por classe para validar (isso é pouco!). Pode gerar variações grandes nos resultados se usar imagens novas.
#
# Conclusão da análise do primeiro resultado:
# O modelo treinado por 40 épocas apresenta excelente performance para identificação básica dos objetos, mas ainda precisa melhorar para ser mais preciso em detectar com alta exigência (mAP50-95). Pode também haver risco de overfitting e seria interessante testar com mais dados ou aplicar técnicas de regularização.
#
# MODELO 2) Informações observadas:
#
# • **Épocas: 60**
# • Tempo de treino: ~1.27 horas (mais rápido que o anterior)
# • Classes: 4 classes
# • mAP50: 78%
# • mAP50-95: 58.7%
# • Precision (P): 0.78
# • Recall (R): 0.587
# Classes individuais:
# • Copo: mAP50 = 99.5%, mAP50-95 = 85.2% (ótimo para copo)
# • Estante: mAP50 = 56.5%, mAP50-95 = 32.2% (baixo para estante)
#
# Análise:
# 1. Assertividade do modelo:
# • O modelo piorou no geral comparado ao de 40 épocas:
# • mAP50 caiu de 100% para 78%.
# • mAP50-95 caiu de 69.7% para 58.7%.
# • Precision e Recall também caíram em geral.
# Porém, o copo continua sendo identificado muito bem:
# • mAP50 = 99.5% (excelente).
# • mAP50-95 = 85.2% (melhor que no anterior!).
# Então para o copo, seu modelo ficou até melhor em precisão de detecção fina.
# Mas para a “estante” (provavelmente um objeto mais difícil ou mais variável nas imagens), o desempenho caiu bastante.
#
# **Comparação dos dois treinos:**
# • Treino com 40 épocas está mais equilibrado entre as classes (mesmo que com múltiplas caixas).
# • Treino com 60 épocas ficou muito bom para detectar copo, mas piorou muito para objetos como estante.
# • Generalização pior no de 60 épocas: não é o ideal para um modelo robusto de vários tipos de objeto.
